# %% [markdown]
# Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/processed/ecommerce.csv")

# %% [markdown]
# # 1. Dataset Overview
#
# Tahapan ini bertujuan untuk mengetahui ukuran dataset, struktur kolom, tipe data, dan contoh isi data.

# %%
df.head()
# Out:
#    keyword   product_id                                       product_name  \
# 0  headset  42531428335  VIVAN Earphone Headphone Headset In-Ear 3D Sub...
# 1  headset  25117212844  Lenovo Thinkplus TH30 Headset Bluetooth V5.3 W...
# 2  headset    826361914  Xiaomi In-Ear Headphones Basic | Built-in Micr...
# 3  headset  40651424918  Pods Air Headset EarPods Kabel Earphone Handsf...
# 4  headset  43662379094  Baseus Bass BH1 Lite Wireless Headphone Super ...
#
#                                                  url currency  \
# 0  https://shopee.co.id/VIVAN-Earphone-Headphone-...      IDR
# 1  https://shopee.co.id/Lenovo-Thinkplus-TH30-Hea...      IDR
# 2  https://shopee.co.id/Xiaomi-In-Ear-Headphones-...      IDR
# 3  https://shopee.co.id/Pods-Air-Headset-EarPods-...      IDR
# 4  https://shopee.co.id/Baseus-Bass-BH1-Lite-Wire...      IDR
#
#    original_price_min  original_price_max  final_price_min  final_price_max  \
# ...

# %%
df.tail()
# Out:
#     keyword   product_id                                       product_name  \
# 245  tablet  53607413967  [Gratis Mouse Keyboard]Hancdon Tablet Pro12 (1...
# 246  tablet  29992703113  Xiaomi Pad 7 Pro (12/512GB) | Snapdragon 8S Ge...
# 247  tablet  28771927934  SMARTBERRY KIDS STUDY TAB B93 tab 4/128GB / An...
# 248  tablet  40159192477     ADVAN TAB A10 (4/64GB) WIFI ONLY BATRE 5000MAH
# 249  tablet  28005273876  ADVAN TAB VX NEO 4GB/128GB 10.1”IPS SCREEN TAB...
#
#                                                    url currency  \
# 245  https://shopee.co.id/-Gratis-Mouse-Keyboard-Ha...      IDR
# 246  https://shopee.co.id/Xiaomi-Pad-7-Pro-(12-512G...      IDR
# 247  https://shopee.co.id/SMARTBERRY-KIDS-STUDY-TAB...      IDR
# 248  https://shopee.co.id/ADVAN-TAB-A10-(4-64GB)-WI...      IDR
# 249  https://shopee.co.id/ADVAN-TAB-VX-NEO-4GB-128G...      IDR
#
#      original_price_min  original_price_max  final_price_min  final_price_max  \
# ...

# %%
df.shape
# Out:
# (250, 32)

# %%
df.columns
# Out:
# Index(['keyword', 'product_id', 'product_name', 'url', 'currency',
#        'original_price_min', 'original_price_max', 'final_price_min',
#        'final_price_max', 'discount_percent', 'category_1', 'category_2',
#        'category_3', 'rating', 'review_count', 'sold', 'star_1', 'star_2',
#        'star_3', 'star_4', 'star_5', 'seller_id', 'seller_name',
#        'seller_rating', 'seller_followers', 'seller_product',
#        'seller_response_rate', 'seller_response_time', 'seller_joined',
#        'price_avg', 'price_range', 'seller_age'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   keyword               250 non-null    str
#  1   product_id            250 non-null    int64
#  2   product_name          250 non-null    str
#  3   url                   250 non-null    str
#  4   currency              250 non-null    str
#  5   original_price_min    250 non-null    float64
#  6   original_price_max    250 non-null    float64
#  7   final_price_min       250 non-null    float64
#  8   final_price_max       250 non-null    float64
#  9   discount_percent      250 non-null    int64
#  10  category_1            250 non-null    str
#  11  category_2            250 non-null    str
#  12  category_3            250 non-null    str
#  13  rating                245 non-null    float64
#  14  review_count          250 non-null    float64
# ...

# %% [markdown]
# # 2. Data Quality
#
# Tahapan ini bertujuan untuk memastikan kualitas dataset sebelum dilakukan analisis.

# %%
df.isnull().sum()
# Out:
# keyword                 0
# product_id              0
# product_name            0
# url                     0
# currency                0
# original_price_min      0
# original_price_max      0
# final_price_min         0
# final_price_max         0
# discount_percent        0
# category_1              0
# category_2              0
# category_3              0
# rating                  5
# review_count            0
# sold                    0
# star_1                  0
# star_2                  0
# star_3                  0
# star_4                  0
# star_5                  0
# seller_id               0
# seller_name             0
# seller_rating           0
# seller_followers        0
# seller_product          0
# seller_response_rate    0
# seller_response_time    0
# seller_joined           0
# price_avg               0
# price_range             0
# seller_age              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# keyword                     str
# product_id                int64
# product_name                str
# url                         str
# currency                    str
# original_price_min      float64
# original_price_max      float64
# final_price_min         float64
# final_price_max         float64
# discount_percent          int64
# category_1                  str
# category_2                  str
# category_3                  str
# rating                  float64
# review_count            float64
# sold                    float64
# star_1                  float64
# star_2                  float64
# star_3                  float64
# star_4                  float64
# star_5                  float64
# seller_id                 int64
# seller_name                 str
# seller_rating           float64
# seller_followers        float64
# seller_product          float64
# seller_response_rate    float64
# seller_response_time      int64
# seller_joined               str
# ...

# %% [markdown]
# ## Insight
#
# Dataset tidak memiliki duplicate dan seluruh tipe data telah sesuai dengan kebutuhan analisis.

# %% [markdown]
# # 3. Statistik Deskriptif
#
# Statistik deskriptif digunakan untuk mengetahui karakteristik umum setiap variabel numerik.

# %%
df.describe().T
# Out:
#                       count          mean           std          min  \
# product_id            250.0  3.336617e+10  1.497719e+10  545082409.0
# original_price_min    250.0  4.264358e+06  4.680755e+06      22000.0
# original_price_max    250.0  4.549178e+06  5.023062e+06      22000.0
# final_price_min       250.0  4.066316e+06  4.649063e+06      11500.0
# final_price_max       250.0  4.340786e+06  4.999645e+06      11500.0
# discount_percent      250.0  1.290000e+01  2.360132e+01          0.0
# rating                245.0  4.885714e+00  1.355015e-01          4.1
# review_count          250.0  1.749976e+03  6.107862e+03          0.0
# sold                  250.0  1.770056e+03  2.855691e+03          0.0
# star_1                250.0  1.148000e+01  2.996507e+01          0.0
# star_2                250.0  5.400000e+00  1.582307e+01          0.0
# star_3                250.0  1.926800e+01  6.419032e+01          0.0
# star_4                250.0  1.069800e+02  3.910587e+02          0.0
# ...

# %% [markdown]
# ## Insight
#
# Dari statistik deskriptif dapat diketahui nilai minimum, maksimum, rata-rata, median, serta persebaran masing-masing variabel.

# %% [markdown]
# # 4. Distribusi Harga Produk

# %%
plt.figure(figsize=(10,5))

plt.hist(df["price_avg"], bins=25, color="tomato", edgecolor="black")

plt.title("Distribution of Product Price")
plt.xlabel("Price (Million IDR)")
plt.ylabel("Frequency")

formatter = FuncFormatter(lambda x, pos: f'{x/1_000_000:.0f}')
plt.gca().xaxis.set_major_formatter(formatter)

plt.show()

# %% [markdown]
# ## Insight
#
# Grafik menunjukkan distribusi harga produk pada dataset.

# %% [markdown]
# # 5. Distribusi Rating Produk

# %%
plt.figure(figsize=(8,5))

plt.hist(df["rating"], bins=20)

plt.title("Distribution of Rating")

plt.xlabel("Rating")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # 6. Distribusi Jumlah Review

# %%
plt.figure(figsize=(8,5))

plt.hist(df["review_count"], bins=30)

plt.title("Distribution of Review Count")

plt.xlabel("Review")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # 7. Distribusi Jumlah Penjualan

# %%
plt.figure(figsize=(8,5))

plt.hist(df["sold"], bins=30)

plt.title("Distribution of Sold Product")

plt.xlabel("Sold")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # 8. Distribusi Persentase Diskon

# %%
plt.figure(figsize=(8,5))

plt.hist(df["discount_percent"], bins=20)

plt.title("Distribution of Discount")

plt.xlabel("Discount (%)")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # 9. Distribusi Keyword

# %%
keyword = df["keyword"].value_counts()

keyword.plot(kind="bar")

plt.title("Number of Products by Keyword")

plt.ylabel("Total Product")

plt.show()

# %% [markdown]
# # 10. Distribusi Kategori Produk

# %%
category = df["category_2"].value_counts()

category.plot(kind="bar")

plt.title("Product Category")

plt.ylabel("Total Product")

plt.show()

# %% [markdown]
# # 11. Top 10 Seller Berdasarkan Penjualan

# %%
seller = (
    df.groupby("seller_name")["sold"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

seller.plot(kind="bar")

plt.title("Top 10 Sellers by Total Sales")

plt.ylabel("Total Sold")

plt.show()

# %% [markdown]
# # 12. Outlier Harga Produk

# %%
plt.figure(figsize=(6,5))

plt.boxplot(df["price_avg"])

plt.title("Boxplot Price")

plt.show()

# %% [markdown]
# # 13. Outlier Jumlah Penjualan

# %%
plt.figure(figsize=(6,5))

plt.boxplot(df["sold"])

plt.title("Boxplot Sold")

plt.show()

# %% [markdown]
# # 14. Scatter Plot Harga vs Penjualan
#
# Scatter plot digunakan hanya untuk melihat pola hubungan antar variabel secara visual.
#
# Analisis korelasi akan dilakukan pada notebook berikutnya.

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["price_avg"],
    df["sold"],
    alpha=0.5
)

plt.xlabel("Price")

plt.ylabel("Sold")

plt.title("Price vs Sold")

plt.show()

# %% [markdown]
# # Kesimpulan EDA
#
# Berdasarkan hasil eksplorasi dapat disimpulkan bahwa:
#
# - Dataset berhasil diproses dengan baik.
# - Tidak ditemukan permasalahan kualitas data yang signifikan.
# - Variabel numerik telah siap digunakan pada analisis lanjutan.
# - Distribusi harga dan jumlah penjualan menunjukkan adanya variasi yang cukup besar.
# - Terdapat beberapa outlier pada variabel harga maupun jumlah penjualan yang perlu diperhatikan pada tahap pemodelan.
# - Dataset telah memenuhi kebutuhan untuk analisis korelasi, regresi, klasifikasi, dan clustering.
